# %%
from compas.datastructures import Mesh
import compas.geometry as cg
import numpy as np
from compas_viewer import Viewer

# %%
A = cg.Point(0,0,0)
B = cg.Point(0,1,0)
C = cg.Point(1,0,0)
D = cg.Point(1,1,0)
E = cg.Point(1.5,1,0)
E = cg.Point(1,1.5,0)
pl1=cg.Polygon([A, B, D])
pl2=cg.Polygon([A, C, D])
pl3=cg.Polygon([D, E, B])
pl4=cg.Polygon([D, E, C])
mesh = Mesh.from_polygons([pl1, pl2, pl3, pl4])

# view = Viewer()
# view.scene.add(mesh)
# view.show()

# %%
ls = list(mesh.vertex_gkey())
print(ls)
mesh.vk
# Out:
# [0, 1, 2, 3, 4]
